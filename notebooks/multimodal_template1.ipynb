# %% [markdown]
# <a href="https://colab.research.google.com/github/informatics-isi-edu/eye-ai-exec/blob/main/notebooks/VGG19_Diagnosis_Train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multimodal Template

# %%
# import sys
# IN_COLAB = 'google.colab' in sys.modules

# if IN_COLAB:
#     !pip install deriva
#     !pip install bdbag
#     !pip install --upgrade --force pydantic
#     !pip install git+https://github.com/informatics-isi-edu/deriva-ml git+https://github.com/informatics-isi-edu/eye-ai-ml

# %%
repo_dir = "Repos"   # Set this to be where your github repos are located.
# %load_ext autoreload
# %autoreload 2

# Update the load path so python can find modules for the model
import sys
from pathlib import Path
sys.path.insert(0, str(Path.home() / repo_dir / "eye-ai-ml"))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Prerequisites

import json
import os
from eye_ai.eye_ai import EyeAI
import pandas as pd
from pathlib import Path, PurePath
import logging
# import torch

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', force=True)

# %%
from deriva.core.utils.globus_auth_utils import GlobusNativeLogin
catalog_id = "eye-ai" #@param
host = 'www.eye-ai.org'


gnl = GlobusNativeLogin(host=host)
if gnl.is_logged_in([host]):
    print("You are already logged in.")
else:
    gnl.login([host], no_local_server=True, no_browser=True, refresh_tokens=True, update_bdbag_keychain=True)
    print("Login Successful")
# Out:
# 2024-05-30 14:02:46,965 - INFO - Creating client of type <class 'globus_sdk.services.auth.client.native_client.NativeAppAuthClient'> for service "auth"
# 2024-05-30 14:02:46,966 - INFO - Finished initializing AuthLoginClient. client_id='8ef15ba9-2b4a-469c-a163-7fd910c9d111', type(authorizer)=<class 'globus_sdk.authorizers.base.NullAuthorizer'>
# You are already logged in.

# %% [markdown]
# Connect to Eye-AI catalog.  Configure to store data local cache and working directories.  Initialize Eye-AI for pending execution based on the provided configuration file.

# %%
# Variables to configure the rest of the notebook.

cache_dir = '/data'        # Directory in which to cache materialized BDBags for datasets
working_dir = '/data'    # Directory in which to place output files for later upload.

configuration_rid="2-BDA8" # rid

# %%
EA = EyeAI(hostname = host, catalog_id = catalog_id, cache_dir= cache_dir, working_dir=working_dir)
# Out:
# 2024-05-30 14:02:51,195 - INFO - Creating client of type <class 'globus_sdk.services.auth.client.native_client.NativeAppAuthClient'> for service "auth"
# 2024-05-30 14:02:51,196 - INFO - Finished initializing AuthLoginClient. client_id='8ef15ba9-2b4a-469c-a163-7fd910c9d111', type(authorizer)=<class 'globus_sdk.authorizers.base.NullAuthorizer'>

# %%
# @title Initiate an Execution
configuration_records = EA.execution_init(configuration_rid=configuration_rid)
configuration_records.model_dump()

# %%
# View data

# subject = pd.read_csv(configuration_records.bag_paths[0]/'data/Subject.csv')
# subject

# observation = pd.read_csv(configuration_records.bag_paths[0]/'data/Observation.csv')
# observation

# clinic = pd.read_csv(configuration_records.bag_paths[0]/'data/Clinical_Records.csv')
# clinic

# observation_clinic_asso = pd.read_csv(configuration_records.bag_paths[0]/'data/Observation_Clinic_Asso.csv')
# observation_clinic_asso # association table between observation table and clinic record table

# icd10 = pd.read_csv(configuration_records.bag_paths[0]/'data/Clinic_ICD10.csv')
# icd10

# icd10_asso = pd.read_csv(configuration_records.bag_paths[0]/'data/Clinic_ICD_Asso.csv')
# icd10_asso # association table between clinic record table and ICD10 code

# report = pd.read_csv(configuration_records.bag_paths[0]/'data/Report.csv')
# report

# RNFL_OCR = pd.read_csv(configuration_records.bag_paths[0]/'data/RNFL_OCR.csv')
# RNFL_OCR

HVF_OCR = pd.read_csv(configuration_records.bag_paths[0]/'data/HVF_OCR.csv')
HVF_OCR
# Out:
#          RID                            RCT                            RMT  \
# 0     2-B93Y  2024-05-20 23:15:48.182905+00  2024-05-20 23:15:48.182905+00
# 1     2-B940  2024-05-20 23:15:48.182905+00  2024-05-20 23:15:48.182905+00
# 2     2-B942  2024-05-20 23:15:48.182905+00  2024-05-20 23:15:48.182905+00
# 3     2-B944  2024-05-20 23:15:48.182905+00  2024-05-20 23:15:48.182905+00
# 4     2-B946  2024-05-20 23:15:48.182905+00  2024-05-20 23:15:48.182905+00
# ...      ...                            ...                            ...
# 2144  2-BD9Y  2024-05-20 23:59:49.438927+00  2024-05-20 23:59:49.438927+00
# 2145  2-BDA0  2024-05-20 23:59:49.438927+00  2024-05-20 23:59:49.438927+00
# 2146  2-BDA2  2024-05-20 23:59:49.438927+00  2024-05-20 23:59:49.438927+00
# 2147  2-BDA4  2024-05-20 23:59:49.438927+00  2024-05-20 23:59:49.438927+00
# 2148  2-BDA6  2024-05-20 23:59:49.438927+00  2024-05-20 23:59:49.438927+00
#
#                                                     RCB  \
# 0     https://auth.globus.org/3769492a-b197-4063-952...
# 1     https://auth.globus.org/3769492a-b197-4063-952...
# 2     https://auth.globus.org/3769492a-b197-4063-952...
# 3     https://auth.globus.org/3769492a-b197-4063-952...
# 4     https://auth.globus.org/3769492a-b197-4063-952...
# ...                                                 ...
# 2144  https://auth.globus.org/3769492a-b197-4063-952...
# 2145  https://auth.globus.org/3769492a-b197-4063-952...
# 2146  https://auth.globus.org/3769492a-b197-4063-952...
# 2147  https://auth.globus.org/3769492a-b197-4063-952...
# 2148  https://auth.globus.org/3769492a-b197-4063-952...
#
#                                                     RMB Field_Size  \
# 0     https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 1     https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 2     https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 3     https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 4     https://auth.globus.org/3769492a-b197-4063-952...       24-2
# ...                                                 ...        ...
# 2144  https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 2145  https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 2146  https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 2147  https://auth.globus.org/3769492a-b197-4063-952...       24-2
# 2148  https://auth.globus.org/3769492a-b197-4063-952...       24-2
#
#            Strategy False_Neg False_Pos Fixation_Loss  ... Visual_Acuity  \
# 0     SITA Standard        5%        7%          5/15  ...         20/30
# 1         SITA Fast       Off        0%           NaN  ...           NaN
# 2     SITA Standard        0%        0%          0/15  ...           NaN
# 3     SITA Standard        0%        1%          0/15  ...         20/30
# 4         SITA Fast        0%        0%          0/11  ...         20/20
# ...             ...       ...       ...           ...  ...           ...
# 2144      SITA Fast       Off        3%           NaN  ...         20/30
# 2145      SITA Fast        0%     17%XX          1/10  ...         20/25
# 2146  SITA Standard        0%        0%           NaN  ...           NaN
# 2147      SITA Fast       Off        0%           NaN  ...         20/30
# 2148      SITA Fast       Off       NaN           NaN  ...         20/30
#
#                         GHT   PSD.1  \
# 0     Outside Normal Limits    5.19
# 1     Outside Normal Limits    7.85
# 2     Outside Normal Limits    5.12
# 3      Within Normal Limits     NaN
# 4      Within Normal Limits     NaN
# ...                     ...     ...
# 2144  Outside Normal Limits  865.00
# 2145   Within Normal Limits     NaN
# 2146   Within Normal Limits     NaN
# 2147  Outside Normal Limits    2.19
# 2148   Within Normal Limits     NaN
#
#                                                Abs_Perc  \
# 0      \n                                     \n\n  ...
# 1      \n                                     \n\n  ...
# 2      \n                                     \n\n  ...
# 3      \n                                     \n\n  ...
# 4      \n                                     \n\n  ...
# ...                                                 ...
# 2144   \n                                     \n\n  ...
# 2145   \n                                     \n\n  ...
# 2146   \n                                     \n\n  ...
# 2147   \n                                     \n\n  ...
# 2148   \n                                     \n\n  ...
#
#                                                 Abs_Val  \
# 0      \n                                       \n\n...
# 1      \n                                       \n\n...
# 2      \n                                       \n\n...
# 3      \n                                       \n\n...
# 4      \n                                       \n\n...
# ...                                                 ...
# 2144   \n                                       \n\n...
# 2145   \n                                       \n\n...
# 2146   \n                                       \n\n...
# 2147   \n                                       \n\n...
# 2148   \n                                       \n\n...
#
#                                                Pat_Perc  \
# 0      \n                                     \n\n  ...
# 1      \n                                     \n\n  ...
# 2      \n                                     \n\n  ...
# 3      \n                                     \n\n  ...
# 4      \n                                     \n\n  ...
# ...                                                 ...
# 2144   \n                                     \n\n  ...
# 2145   \n                                     \n\n  ...
# 2146   \n                                     \n\n  ...
# 2147   \n                                     \n\n  ...
# 2148   \n                                     \n\n  ...
#
#                                                 Pat_Val  \
# 0      \n                                       \n\n...
# 1      \n                                       \n\n...
# 2      \n                                       \n\n...
# 3      \n                                       \n\n...
# 4      \n                                       \n\n...
# ...                                                 ...
# 2144   \n                                       \n\n...
# 2145   \n                                       \n\n...
# 2146   \n                                       \n\n...
# 2147   \n                                       \n\n...
# 2148   \n                                       \n\n...
#
#                                                 Raw_Val  Report  \
# 0      \n                                       \n\n...  2-ATX0
# 1      \n                                       \n\n...  2-ATX8
# 2      \n                                       \n\n...  2-ATXG
# 3      \n                                       \n\n...  2-ATXM
# 4      \n                                       \n\n...  2-ATXR
# ...                                                 ...     ...
# 2144   \n                                       \n\n...  2-B2E6
# 2145   \n                                       \n\n...  2-B2EA
# 2146   \n                                       \n\n...  2-B2EM
# 2147   \n                                       \n\n...  2-B2EW
# 2148   \n                                       \n\n...  2-B2F4
#
#      Image_Side_Vocab
# 0                2SK2
# 1                2SK2
# 2                2SK2
# 3                2SK2
# 4                2SK2
# ...               ...
# 2144             2SK0
# 2145             2SK0
# 2146             2SK0
# 2147             2SK0
# 2148             2SK0
#
# [2149 rows x 32 columns]

# %%
# @title Execute Training algorithm
from eye_ai.models.vgg19_hyper_parameter_tuning import main #import the new logistic module.
with EA.execution(execution_rid=configuration_records.execution_rid) as exec:
  main()

# %%
# @title Save Execution Assets (model) and Metadata
uploaded_assets = EA.execution_upload(configuration_records.execution_rid, False)

# %% [markdown]
# #
